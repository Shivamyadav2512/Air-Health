# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
data = pd.read_csv('airdata/Delhi-2003.csv')
data=data.rename(columns = {'Sampling Date':'Sampling_Date'})
for i in range(data.shape[0]):
    
    if '-' in data['Sampling_Date'][i]:
        data['Sampling_Date'][i] = pd.to_datetime(data['Sampling_Date'][i],format = '%d-%m-%y')
        
    else:
        data['Sampling_Date'][i] = pd.to_datetime(data['Sampling_Date'][i],format = '%d/%m/%Y')
        

print data.Sampling_Date


    
data.index = data['Sampling_Date']
data = data.sort_values(by='Sampling_Date')
del data['Sampling_Date']
print data
# Out:
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0      2003-01-01 00:00:00
# 1      2003-06-01 00:00:00
# 2      2003-09-01 00:00:00
# 3      2003-01-14 00:00:00
# 4      2003-01-17 00:00:00
# 5      2003-01-22 00:00:00
# 6      2003-01-27 00:00:00
# 7      2003-01-30 00:00:00
# 8      2003-05-02 00:00:00
# 9      2003-10-02 00:00:00
# 10     2003-02-14 00:00:00
# 11     2003-02-19 00:00:00
# ...

# %%
for j in range(2004,2016):
    if(j==2010):
        continue
    print j
    filey = 'airdata/Delhi-'+str(j)+'.csv'
    data2 = pd.read_csv(filey)
    data2=data2.rename(columns = {'Sampling Date':'Sampling_Date'})
    for i in range(data2.shape[0]):
    
        if '-' in data2['Sampling_Date'][i]:
            data2['Sampling_Date'][i] = pd.to_datetime(data2['Sampling_Date'][i],format = '%d-%m-%y')
        
        else:
            data2['Sampling_Date'][i] = pd.to_datetime(data2['Sampling_Date'][i],format = '%d/%m/%Y')
    
    data2.index = data2['Sampling_Date']
    data2 = data2.sort_values(by='Sampling_Date')
    del data2['Sampling_Date']
    
    
    data = pd.concat([data,data2])
# Out:
# 2004
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# 2005
# 2006
# 2007
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015

# %%
print data
# Out:
#                                                           Agency  \
# Sampling_Date
# 2003-01-01                       Central Pollution Control Board
# 2003-01-01                       Central Pollution Control Board
# 2003-01-04                                                   NaN
# 2003-01-04                       Central Pollution Control Board
# 2003-01-04                                                   NaN
# 2003-01-04                       Central Pollution Control Board
# 2003-01-04                                                   NaN
# 2003-01-07                                                   NaN
# 2003-01-07                       Central Pollution Control Board
# 2003-01-07                                                   NaN
# 2003-01-07                                                   NaN
# 2003-01-07                       Central Pollution Control Board
# 2003-01-08                       Central Pollution Control Board
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2003-01-01', '2003-01-01', '2003-01-04', '2003-01-04',
#                '2003-01-04', '2003-01-04', '2003-01-04', '2003-01-07',
#                '2003-01-07', '2003-01-07',
#                ...
#                '2015-12-29', '2015-12-29', '2015-12-30', '2015-12-30',
#                '2015-12-30', '2015-12-30', '2015-12-30', '2015-12-31',
#                '2015-12-31', '2015-12-31'],
#               dtype='datetime64[ns]', name=u'Sampling_Date', length=7221, freq=None)

# %%
area1 = data.loc[data['Location of Monitoring Station'] == 'Shahdara']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-fab6324c1cd2> in <module>()
# ----> 1 area1 = data.loc[data['Location of Monitoring Station'] == 'Shahdara']
#
# /home/demonicode/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /home/demonicode/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
ts = area1['RSPM/PM10'] 
ts.head(10)
# Out:
# Sampling_Date
# 2005-01-08     54.0
# 2005-01-09     97.0
# 2005-01-13    121.0
# 2005-01-18    113.0
# 2005-01-24     64.0
# 2005-01-28     73.0
# 2005-02-03     71.0
# 2005-02-16    142.0
# 2005-02-21    181.0
# 2005-02-24    148.0
# Name: RSPM/PM10, dtype: float64

# %%
plt.plot(ts)

# %%
data=data.rename(columns = {'Location of Monitoring Station':'Location_of_Monitoring_Station'})

list_of_areas = data.Location_of_Monitoring_Station.unique()
print list_of_areas
# Out:
# [nan 'Shahadra, Delhi' 'Janakpuri, Delhi' 'Ashok Vihar, Delhi'
#  'Siri Fort, Delhi' 'Nizamuddin, Delhi' 'Shahzada Bagh, Delhi' 'Siri Fort'
#  'Town Hall, Ayurvedic Dispensary, Chandni Chowk, Delhi'
#  'N.Y. SCHOOL, Sarojini Nagar, Delhi' 'Shahzada Bagh'
#  'Mayapuri Industrial Area, Delhi' 'DCE' 'BSZ Marg' 'Janakpuri'
#  'Pritampura, Delhi']

# %%
#data['Location_of_Monitoring_Station'].replace({'Nizamuddin': 'Nizamuddin, Delhi', 'Pritampura': 'Pritampura, Delhi', 'N.Y. School': 'N.Y. SCHOOL, Sarojini Nagar, Delhi'})
data.replace('Nizamuddin', 'Nizamuddin, Delhi',inplace=True)
data.replace('Pritampura', 'Pritampura, Delhi',inplace=True)
data.replace('Shahdara', 'Shahadra, Delhi',inplace=True)
data.replace('Town Hall', 'Town Hall, Ayurvedic Dispensary, Chandni Chowk, Delhi',inplace=True)
data.replace('Mayapuri Indl. Area', 'Mayapuri Industrial Area, Delhi',inplace=True)
data.replace('Ashok Vihar', 'Ashok Vihar, Delhi',inplace=True)
data.replace('N.Y. School', 'N.Y. SCHOOL, Sarojini Nagar, Delhi',inplace=True)
data.replace('Siri Fort', 'Siri Fort, Delhi',inplace=True)
data.replace('Shahzada Bagh', 'Shahzada Bagh, Delhi',inplace=True)
data.replace('Janakpuri', 'Janakpuri, Delhi',inplace=True)

list_of_areas = data.Location_of_Monitoring_Station.unique()
print list_of_areas
# Out:
# [nan 'Shahadra, Delhi' 'Janakpuri, Delhi' 'Ashok Vihar, Delhi'
#  'Siri Fort, Delhi' 'Nizamuddin, Delhi' 'Shahzada Bagh, Delhi'
#  'Town Hall, Ayurvedic Dispensary, Chandni Chowk, Delhi'
#  'N.Y. SCHOOL, Sarojini Nagar, Delhi' 'Mayapuri Industrial Area, Delhi'
#  'DCE' 'BSZ Marg' 'Pritampura, Delhi']

# %%
data.drop_duplicates(inplace=True)


list_of_areas = data.Location_of_Monitoring_Station.unique()
print list_of_areas
# Out:
# [nan 'Shahadra, Delhi' 'Janakpuri, Delhi' 'Ashok Vihar, Delhi'
#  'Siri Fort, Delhi' 'Nizamuddin, Delhi' 'Shahzada Bagh, Delhi'
#  'Town Hall, Ayurvedic Dispensary, Chandni Chowk, Delhi'
#  'N.Y. SCHOOL, Sarojini Nagar, Delhi' 'Mayapuri Industrial Area, Delhi'
#  'DCE' 'BSZ Marg' 'Pritampura, Delhi']

# %%
print data[data.Location_of_Monitoring_Station=='BSZ Marg']
# Out:
#               Agency City/Town/Village/Area Location_of_Monitoring_Station  \
# Sampling_Date
# 2005-01-07       NaN                  Delhi                       BSZ Marg
# 2005-01-08       NaN                  Delhi                       BSZ Marg
# 2005-01-09       NaN                  Delhi                       BSZ Marg
# 2005-02-07       NaN                  Delhi                       BSZ Marg
# 2005-02-08       NaN                  Delhi                       BSZ Marg
# 2005-02-09       NaN                  Delhi                       BSZ Marg
# 2005-03-07       NaN                  Delhi                       BSZ Marg
# 2005-03-08       NaN                  Delhi                       BSZ Marg
# 2005-03-09       NaN                  Delhi                       BSZ Marg
# 2005-04-07       NaN                  Delhi                       BSZ Marg
# 2005-04-08       NaN                  Delhi                       BSZ Marg
# ...

# %%
for area in list_of_areas:
    print area
    area1 = data.loc[data['Location_of_Monitoring_Station'] == area]
    ts = area1['RSPM/PM10'] 
    ts.head(10)
    plt.plot(ts)
    plt.show()
# Out:
# nan
# Shahadra, Delhi
# Janakpuri, Delhi
# Ashok Vihar, Delhi
# Siri Fort, Delhi
# Nizamuddin, Delhi
# Shahzada Bagh, Delhi
# Town Hall, Ayurvedic Dispensary, Chandni Chowk, Delhi
# N.Y. SCHOOL, Sarojini Nagar, Delhi
# Mayapuri Industrial Area, Delhi
# DCE
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/demonicode/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /home/demonicode/anaconda2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# ...

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print 'Results of Dickey-Fuller Test:'
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print dfoutput

# %%
from datetime import datetime

temp_data = data[datetime(2011, 1, 1):]

print temp_data
# Out:
#                                                           Agency  \
# Sampling_Date
# 2011-01-02                       Central Pollution Control Board
# 2011-01-02                       Central Pollution Control Board
# 2011-01-02     National Environmental Engineering Research In...
# 2011-01-03     National Environmental Engineering Research In...
# 2011-01-03                       Central Pollution Control Board
# 2011-01-03     National Environmental Engineering Research In...
# 2011-01-03                       Central Pollution Control Board
# 2011-01-04                       Central Pollution Control Board
# 2011-01-04                       Central Pollution Control Board
# 2011-01-06     National Environmental Engineering Research In...
# 2011-01-06     National Environmental Engineering Research In...
# 2011-01-06                       Central Pollution Control Board
# 2011-01-06                       Central Pollution Control Board
# ...

# %%
#temp_data[data.index.duplicated()]


temp_data.drop_duplicates(inplace=True)
print temp_data
#data[data.index.duplicated()]
# Out:
#                                                           Agency  \
# Sampling_Date
# 2011-01-02                       Central Pollution Control Board
# 2011-01-02                       Central Pollution Control Board
# 2011-01-02     National Environmental Engineering Research In...
# 2011-01-03     National Environmental Engineering Research In...
# 2011-01-03                       Central Pollution Control Board
# 2011-01-03     National Environmental Engineering Research In...
# 2011-01-03                       Central Pollution Control Board
# 2011-01-04                       Central Pollution Control Board
# 2011-01-04                       Central Pollution Control Board
# 2011-01-06     National Environmental Engineering Research In...
# 2011-01-06     National Environmental Engineering Research In...
# 2011-01-06                       Central Pollution Control Board
# 2011-01-06                       Central Pollution Control Board
# ...

# %%
area1 = temp_data.loc[data['Location_of_Monitoring_Station'] == 'Town Hall, Ayurvedic Dispensary, Chandni Chowk, Delhi']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-ac4055a15e43> in <module>()
#       1
#       2
# ----> 3 area1 = temp_data.loc[data['Location_of_Monitoring_Station'] == 'Town Hall, Ayurvedic Dispensary, Chandni Chowk, Delhi']
#
# /home/demonicode/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /home/demonicode/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1506             return self._get_slice_axis(key, axis=axis)
#    1507         elif is_bool_indexer(key):
# -> 1508             return self._getbool_axis(key, axis=axis)
# ...

# %%
ts = area1['RSPM/PM10']
ts.dropna(inplace=True)

test_stationarity(ts)
# Out:
# /home/demonicode/anaconda2/lib/python2.7/site-packages/pandas/core/series.py:2726: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(result)
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   import sys
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.061662
# p-value                          0.000017
# #Lags Used                       8.000000
# ...

# %%
plt.plot(ts)
plt.show()
ts_log = np.log(ts)
plt.plot(ts_log)
plt.show()

# %%
moving_avg = pd.rolling_mean(ts_log,12)
plt.plot(ts_log)
plt.plot(moving_avg, color='red')
# Out:
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   """Entry point for launching an IPython kernel.

# %%
ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.head(12)
# Out:
# Sampling_Date
# 2005-01-02         NaN
# 2005-01-03         NaN
# 2005-01-06         NaN
# 2005-01-18         NaN
# 2005-01-19         NaN
# 2005-01-28         NaN
# 2005-01-29         NaN
# 2005-02-02         NaN
# 2005-02-03         NaN
# 2005-02-06         NaN
# 2005-02-08         NaN
# 2005-02-15    0.152073
# Name: RSPM/PM10, dtype: float64

# %%
ts_log_moving_avg_diff.dropna(inplace=True)
test_stationarity(ts_log_moving_avg_diff)
# Out:
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   import sys
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -7.995467e+00
# p-value                        2.410895e-12
# #Lags Used                     1.400000e+01
# Number of Observations Used    8.190000e+02
# Critical Value (5%)           -2.865075e+00
# Critical Value (1%)           -3.438360e+00
# Critical Value (10%)          -2.568653e+00
# dtype: float64

# %%
expwighted_avg = pd.ewma(ts_log, halflife=12)
plt.plot(ts_log)
plt.plot(expwighted_avg, color='red')
# Out:
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(halflife=12,ignore_na=False,min_periods=0,adjust=True).mean()
#   """Entry point for launching an IPython kernel.

# %%
ts_log_ewma_diff = ts_log - expwighted_avg
ts_log_ewma_diff.dropna(inplace=True)
test_stationarity(ts_log_ewma_diff)
# Out:
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   import sys
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -6.482260e+00
# p-value                        1.286320e-08
# #Lags Used                     1.400000e+01
# Number of Observations Used    8.300000e+02
# Critical Value (5%)           -2.865029e+00
# Critical Value (1%)           -3.438253e+00
# Critical Value (10%)          -2.568628e+00
# dtype: float64

# %%
ts_log_diff = ts_log - ts_log.shift()
plt.plot(ts_log_diff)

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   import sys
# /home/demonicode/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -1.684110e+01
# p-value                        1.137944e-29
# #Lags Used                     7.000000e+00
# Number of Observations Used    8.360000e+02
# Critical Value (5%)           -2.865003e+00
# Critical Value (1%)           -3.438196e+00
# Critical Value (10%)          -2.568614e+00
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-9bc023393e6d> in <module>()
#       1 from statsmodels.tsa.seasonal import seasonal_decompose
# ----> 2 decomposition = seasonal_decompose(ts_log)
#       3
#       4 trend = decomposition.trend
#       5 seasonal = decomposition.seasonal
#
# /home/demonicode/anaconda2/lib/python2.7/site-packages/statsmodels/tsa/seasonal.pyc in seasonal_decompose(x, model, filt, freq, two_sided)
#      82             freq = pfreq
#      83         else:
# ---> 84             raise ValueError("You must specify a freq or x must be a "
#      85                              "pandas object with a timeseries index with"
#      86                              "a freq not set to None")
#
# ValueError: You must specify a freq or x must be a pandas object with a timeseries index witha freq not set to None
